# %%
import pytse_client as tse
import numpy as np
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
# tickers = tse.download(symbols="all", write_to_csv=True)

Device = ("cuda"
          if torch.cuda.is_available()
          else "cpu"
)
print(f"Using {Device} device")
days_history=100
days_predict=20
# Out:
# Using cuda device

# %%
class Model(nn.Module):
    def __init__(self,input_size,output_size):
        m=8
        n=32
        output_coeff = 4
        super().__init__()
        self.Lin0 = nn.Linear(5,5*m)
        self.kqv =  nn.Linear(5*m,5*m)
        self.Lin1 = nn.Linear(5*m*input_size,2*n)
        self.normal1 = nn.BatchNorm1d(2*n)
        self.Lin2 = nn.Linear(2*n,4*n)
        self.normal2 = nn.BatchNorm1d(4*n)
        self.Lin3 = nn.Linear(4*n,2*n)
        self.normal3 = nn.BatchNorm1d(2*n)
        self.Lin4 = nn.Linear(2*n,n)
        self.normal4 = nn.BatchNorm1d(n)
        self.Lin5 = nn.Linear(n,output_coeff)
        self.activation1 = nn.LeakyReLU(negative_slope=0.01)
        self.activation2 = nn.Tanh()
        self.drop = nn.Dropout(p=0.9)
        self.multi = nn.MultiheadAttention(5*m,4,batch_first=True,kdim=5*m,vdim=5*m)
        self.flat = nn.Flatten(start_dim=1)
        self.t = torch.zeros([output_coeff,output_size],device=Device)
        for i in range(output_coeff):
            self.t[i,:] = (torch.arange(output_size)+1)**(i) /(0.9*output_size)**i
        
    def forward(self, x):
        x = self.Lin0(x)
        for i in range(2):
            #x0 = x
            k = self.kqv(x)
            q = self.kqv(x)
            v = self.kqv(x)
            x ,_ = self.multi(q,k,v)
            x = self.activation1(x)
            #x = x + x0
        x = self.flat(x)   
        x = self.Lin1(x)
        x = self.normal1(x)
        x = self.activation2(x) 
        x = self.drop(x) ###

        x = self.Lin2(x)
        x = self.normal2(x)
        x = self.activation2(x)
        x = self.drop(x) ###

        x = self.Lin3(x)
        x = self.normal3(x)
        x = self.activation2(x)
        x = self.drop(x) ###

        x = self.Lin4(x)
        x = self.normal4(x)
        x = self.activation1(x)
        x = self.drop(x) ###

        x = self.Lin5(x)
        prediction = x@self.t
        return prediction

model=Model(days_history,days_predict).to(device=Device)
optimizer = torch.optim.Adam(model.parameters(),lr=0.001)
LossFn = nn.MSELoss(reduction='sum')
gama=1.1
W_gama=torch.diag(torch.tensor([gama**(1*i) for i in range(days_predict)],device=Device))
for p in model.parameters():
    #p.data.fill_(torch.randn([])/10)
    print(np.shape(p))
# Out:
# torch.Size([40, 5])
# torch.Size([40])
# torch.Size([40, 40])
# torch.Size([40])
# torch.Size([64, 4000])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([128, 64])
# torch.Size([128])
# torch.Size([128])
# torch.Size([128])
# torch.Size([64, 128])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([32, 64])
# torch.Size([32])
# torch.Size([32])
# torch.Size([32])
# torch.Size([4, 32])
# torch.Size([4])
# torch.Size([120, 40])
# torch.Size([120])
# torch.Size([40, 40])
# torch.Size([40])

# %%
names = ["آباد","آپ","اپرداز","آساس","افرا","اهرم","انرژی","بترانس","بنیرو","پترول"]
sym= names[0]
#sym="وبملت"

ticker=tse.Ticker(sym)
length=ticker.history.shape[0]
train_length = int(np.floor(length*0.70))
test_length = length - train_length

# Now we extract some portion of the first sequences of data for train
X_train=np.zeros([train_length - days_history - days_predict , days_history,5])
Y_train=np.zeros([train_length - days_history - days_predict , days_predict])
for i in range(train_length - days_history - days_predict):
    m = ticker.history.loc[i : i + days_history - 1].to_numpy()
    first_day_price = m[0,9]
    X_train[i,:,:] = np.array([m[:,9]/first_day_price , m[:,7]/1e3 , m[:,6]/1e6 , m[:,2]/m[0,2] , m[:,3]/m[0,3]]).T
    m = ticker.history.loc[i + days_history : i + days_history - 1 + days_predict].to_numpy()
    Y_train[i,:] = m[:,9]/first_day_price

# Now we extract some portion of the last sequences of data for test
X_test=np.zeros([test_length - days_predict , days_history, 5])
Y_test=np.zeros([test_length - days_predict , days_predict])
for i in range(test_length - days_predict):
    j = i + train_length - days_history
    m = ticker.history.loc[j : j + days_history - 1].to_numpy()
    first_day_price = m[0,9]
    X_test[i,:,:] = np.array([m[:,9]/first_day_price , m[:,7]/1e3 , m[:,6]/1e6 , m[:,2]/m[0,2] , m[:,3]/m[0,3]]).T
    m = ticker.history.loc[j + days_history : j + days_history - 1 + days_predict].to_numpy()
    Y_test[i,:] = m[:,9]/first_day_price

train_arr = np.arange(train_length - days_history - days_predict - 1)
train_idx = np.random.permutation(train_arr)
X_train = X_train[train_idx]
Y_train = Y_train[train_idx]

test_arr = np.arange(test_length - days_predict - 1)
test_idx = np.random.permutation(test_arr)
X_test = X_test[test_idx]
Y_test = Y_test[test_idx]
X_train = torch.from_numpy(X_train).to(device=Device,dtype=torch.float32)
Y_train = torch.from_numpy(Y_train).to(device=Device,dtype=torch.float32)

X_test = torch.from_numpy(X_test).to(device=Device,dtype=torch.float32)
Y_test = torch.from_numpy(Y_test).to(device=Device,dtype=torch.float32)

iidx=np.random.randint(test_length-days_predict,size=[5,2])

# %%
batch_size = 64
train_Losses=[]
test_Losses=[]
N_train = int(np.floor(X_train.size(0)/batch_size))
N_test = int(np.floor(X_test.size(0)/batch_size))

for epoch in range(10):
    model.train()
    train_loss=torch.tensor(0,dtype=torch.float32)
    for i in range(N_train):
        x = X_train[i*batch_size:(i+1)*batch_size,:,:]
        y = Y_train[i*batch_size:(i+1)*batch_size,:]
        optimizer.zero_grad()
        out = model(x) + y[:,0].unsqueeze(1)
        loss_train = LossFn(y@W_gama,out@W_gama)
        loss_train.backward()
        #nn.utils.clip_grad_norm(model.parameters(),1)
        optimizer.step()
        train_loss += loss_train.detach().item()
    train_Losses.append( train_loss/(N_train*batch_size*days_predict))
   
    model.eval()
    test_loss=torch.tensor(0,dtype=torch.float32)
    test_acc=torch.tensor(0,dtype=torch.float32)
    with torch.no_grad():
        for i in range(N_test):
            x = X_test[i*batch_size:(i+1)*batch_size,:,:]
            y = Y_test[i*batch_size:(i+1)*batch_size,:].detach()
            out = model(x) + y[:,0].unsqueeze(1) 
            loss_test = LossFn(y@W_gama,out@W_gama)
            test_loss += loss_test.detach().item()
            temp=y-out
            test_acc += torch.sum(1-torch.abs(y-out)/y).detach().item()
    test_Losses.append( test_loss/(N_test*batch_size*days_predict) )
    accuracy = test_acc / (N_test*batch_size*days_predict) *100
    print(f'{epoch}: train loss is {train_Losses[epoch]:.4f} & test loss is {test_Losses[epoch]:.4f} & accuracy is %{accuracy:.2f}')
# Out:
# 0: train loss is 0.4527 & test loss is 1.8847 & accuracy is %55.22
# 1: train loss is 0.4459 & test loss is 1.8798 & accuracy is %55.06
# 2: train loss is 0.4470 & test loss is 1.9058 & accuracy is %55.69
# 3: train loss is 0.4510 & test loss is 1.8875 & accuracy is %55.30
# 4: train loss is 0.4462 & test loss is 1.8719 & accuracy is %54.76
# 5: train loss is 0.4449 & test loss is 1.8761 & accuracy is %54.95
# 6: train loss is 0.4464 & test loss is 1.8887 & accuracy is %55.42
# 7: train loss is 0.4426 & test loss is 1.8658 & accuracy is %54.56
# 8: train loss is 0.4449 & test loss is 1.8770 & accuracy is %55.01
# 9: train loss is 0.4392 & test loss is 1.8768 & accuracy is %55.05
# 10: train loss is 0.4424 & test loss is 1.8855 & accuracy is %55.32
# 11: train loss is 0.4402 & test loss is 1.8746 & accuracy is %54.85
# 12: train loss is 0.4433 & test loss is 1.8811 & accuracy is %55.17
# 13: train loss is 0.4417 & test loss is 1.8885 & accuracy is %55.43
# 14: train loss is 0.4453 & test loss is 1.8777 & accuracy is %55.08
# 15: train loss is 0.4432 & test loss is 1.8901 & accuracy is %55.63
# 16: train loss is 0.4396 & test loss is 1.8694 & accuracy is %54.73
# 17: train loss is 0.4380 & test loss is 1.8777 & accuracy is %55.10
# 18: train loss is 0.4387 & test loss is 1.8707 & accuracy is %54.79
# 19: train loss is 0.4416 & test loss is 1.8827 & accuracy is %55.24
# 20: train loss is 0.4429 & test loss is 1.8845 & accuracy is %55.28
# 21: train loss is 0.4392 & test loss is 1.8805 & accuracy is %55.15
# 22: train loss is 0.4410 & test loss is 1.8834 & accuracy is %55.27
# 23: train loss is 0.4405 & test loss is 1.8834 & accuracy is %55.29
# 24: train loss is 0.4398 & test loss is 1.8789 & accuracy is %55.06
# 25: train loss is 0.4430 & test loss is 1.8719 & accuracy is %54.84
# 26: train loss is 0.4413 & test loss is 1.8849 & accuracy is %55.37
# 27: train loss is 0.4359 & test loss is 1.8748 & accuracy is %54.95
# 28: train loss is 0.4343 & test loss is 1.8817 & accuracy is %55.25
# 29: train loss is 0.4332 & test loss is 1.8690 & accuracy is %54.69
# 30: train loss is 0.4362 & test loss is 1.8702 & accuracy is %54.60
# 31: train loss is 0.4365 & test loss is 1.8756 & accuracy is %54.94
# 32: train loss is 0.4412 & test loss is 1.8819 & accuracy is %55.23
# 33: train loss is 0.4401 & test loss is 1.8819 & accuracy is %55.26
# 34: train loss is 0.4401 & test loss is 1.8937 & accuracy is %55.69
# 35: train loss is 0.4388 & test loss is 1.8708 & accuracy is %54.66
# 36: train loss is 0.4396 & test loss is 1.8686 & accuracy is %54.70
# 37: train loss is 0.4346 & test loss is 1.8657 & accuracy is %54.53
# 38: train loss is 0.4394 & test loss is 1.8747 & accuracy is %54.95
# 39: train loss is 0.4353 & test loss is 1.8739 & accuracy is %54.82
# 40: train loss is 0.4372 & test loss is 1.8734 & accuracy is %54.77
# 41: train loss is 0.4344 & test loss is 1.8821 & accuracy is %55.31
# 42: train loss is 0.4409 & test loss is 1.8771 & accuracy is %55.04
# 43: train loss is 0.4323 & test loss is 1.8783 & accuracy is %55.08
# 44: train loss is 0.4403 & test loss is 1.8706 & accuracy is %54.66
# 45: train loss is 0.4328 & test loss is 1.8680 & accuracy is %54.56
# 46: train loss is 0.4362 & test loss is 1.8850 & accuracy is %55.36
# 47: train loss is 0.4319 & test loss is 1.8727 & accuracy is %54.81
# 48: train loss is 0.4361 & test loss is 1.8895 & accuracy is %55.58
# 49: train loss is 0.4322 & test loss is 1.8725 & accuracy is %54.95
# 50: train loss is 0.4311 & test loss is 1.8450 & accuracy is %53.13
# 51: train loss is 0.4328 & test loss is 1.8745 & accuracy is %54.90
# 52: train loss is 0.4336 & test loss is 1.8846 & accuracy is %55.40
# 53: train loss is 0.4439 & test loss is 1.8620 & accuracy is %54.26
# 54: train loss is 0.4356 & test loss is 1.8766 & accuracy is %55.12
# 55: train loss is 0.4352 & test loss is 1.8846 & accuracy is %55.40
# 56: train loss is 0.4341 & test loss is 1.8862 & accuracy is %55.41
# 57: train loss is 0.4328 & test loss is 1.8573 & accuracy is %53.93
# 58: train loss is 0.4351 & test loss is 1.8788 & accuracy is %55.14
# 59: train loss is 0.4287 & test loss is 1.8738 & accuracy is %54.90
# 60: train loss is 0.4409 & test loss is 1.8812 & accuracy is %55.30
# 61: train loss is 0.4356 & test loss is 1.8644 & accuracy is %54.41
# 62: train loss is 0.4302 & test loss is 1.8834 & accuracy is %55.39
# 63: train loss is 0.4396 & test loss is 1.8812 & accuracy is %55.30
# 64: train loss is 0.4313 & test loss is 1.8764 & accuracy is %55.13
# 65: train loss is 0.4285 & test loss is 1.8688 & accuracy is %54.59
# 66: train loss is 0.4383 & test loss is 1.8834 & accuracy is %55.37
# 67: train loss is 0.4363 & test loss is 1.8777 & accuracy is %55.09
# 68: train loss is 0.4352 & test loss is 1.8738 & accuracy is %54.93
# 69: train loss is 0.4323 & test loss is 1.8828 & accuracy is %55.31
# 70: train loss is 0.4330 & test loss is 1.8712 & accuracy is %54.81
# 71: train loss is 0.4287 & test loss is 1.8801 & accuracy is %55.20
# 72: train loss is 0.4340 & test loss is 1.8769 & accuracy is %55.14
# 73: train loss is 0.4338 & test loss is 1.8703 & accuracy is %54.78
# 74: train loss is 0.4304 & test loss is 1.8669 & accuracy is %54.64
# 75: train loss is 0.4318 & test loss is 1.8751 & accuracy is %55.01
# 76: train loss is 0.4259 & test loss is 1.8716 & accuracy is %54.86
# 77: train loss is 0.4353 & test loss is 1.8717 & accuracy is %54.86
# 78: train loss is 0.4313 & test loss is 1.8668 & accuracy is %54.57
# 79: train loss is 0.4365 & test loss is 1.8727 & accuracy is %54.90
# 80: train loss is 0.4431 & test loss is 1.8786 & accuracy is %55.15
# 81: train loss is 0.4375 & test loss is 1.8894 & accuracy is %55.56
# 82: train loss is 0.4316 & test loss is 1.8830 & accuracy is %55.39
# 83: train loss is 0.4298 & test loss is 1.8781 & accuracy is %55.11
# 84: train loss is 0.4318 & test loss is 1.8822 & accuracy is %55.37
# 85: train loss is 0.4298 & test loss is 1.8820 & accuracy is %55.27
# 86: train loss is 0.4343 & test loss is 1.8739 & accuracy is %55.06
# 87: train loss is 0.4301 & test loss is 1.8780 & accuracy is %55.22
# 88: train loss is 0.4368 & test loss is 1.8891 & accuracy is %55.57
# 89: train loss is 0.4292 & test loss is 1.8604 & accuracy is %54.19
# 90: train loss is 0.4290 & test loss is 1.8713 & accuracy is %54.79
# 91: train loss is 0.4288 & test loss is 1.8689 & accuracy is %54.64
# 92: train loss is 0.4250 & test loss is 1.8749 & accuracy is %54.99
# 93: train loss is 0.4257 & test loss is 1.8741 & accuracy is %54.93
# 94: train loss is 0.4246 & test loss is 1.8778 & accuracy is %55.12
# 95: train loss is 0.4258 & test loss is 1.8769 & accuracy is %55.07
# 96: train loss is 0.4259 & test loss is 1.8901 & accuracy is %55.70
# 97: train loss is 0.4307 & test loss is 1.8817 & accuracy is %55.30
# 98: train loss is 0.4247 & test loss is 1.8704 & accuracy is %54.72
# 99: train loss is 0.4289 & test loss is 1.8705 & accuracy is %54.80

# %%
z = torch.zeros([batch_size,days_predict],device=Device)
const_acc = 0
const_loss = 0
for i in range(N_test):
    x = X_test[i*batch_size:(i+1)*batch_size,:,:]
    y = Y_test[i*batch_size:(i+1)*batch_size,:].detach()
    out = z + y[:,0].unsqueeze(1) 
    loss_const = LossFn(y@W_gama,out@W_gama)
    const_loss += loss_const.detach().item()
    temp=y-out
    const_acc += torch.sum(1-torch.abs(y-out)/y).detach().item()
const_loss /= N_test*batch_size*days_predict
accuracy = const_acc / (N_test*batch_size*days_predict) *100
print(f'constant price method loss is {const_loss:.4f} accuracy is %{accuracy:.2f}')
# Out:
# constant price method loss is 1.8988 accuracy is %56.12

# %%
plt.figure(figsize=[10,12])
model.eval()
for i in range(5):
   plt.subplot(5,2,2*i+1)
   r=iidx[i,0]
   yy=torch.concatenate([X_train[r,:,0].cpu(),Y_train[r,:].cpu()]) 
   xx=np.arange(days_history+days_predict)
   plt.plot(xx,yy)
   tempp=X_train[r,:,:].unsqueeze(0)
   #yyy=(model(tempp).detach()).squeeze(0).cpu()  
   yyy=( (model(tempp).detach()+Y_train[r,0]) ).squeeze(0).cpu()  
   plt.plot(xx[days_history:days_history+days_predict] ,yyy )
   plt.title('train')

   plt.subplot(5,2,2*i+2)
   r=iidx[i,1]
   yy=torch.concatenate([X_test[r,:,0].cpu(),Y_test[r,:].cpu()])
   xx=np.arange(days_history+days_predict)
   plt.plot(xx,yy)
   tempp=X_test[r,:,:].unsqueeze(0)
   #yyy=(model(tempp).detach()).squeeze(0).cpu()  
   yyy=( (model(tempp).detach()+Y_test[r,0]) ).squeeze(0).cpu() 
   plt.plot(xx[days_history:days_history+days_predict] ,yyy )
   plt.title('evaluation')
